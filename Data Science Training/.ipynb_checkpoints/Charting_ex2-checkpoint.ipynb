# %%
import matplotlib.pyplot as plt
# %matplotlib inline
runs = [37,52,60,71,55,30,53,58, 29, 47]
plt.plot(runs)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
runs = [37,52,60,71,55,30,53,58, 29, 47]
tests = np.arange(1,11)
plt.plot(tests,runs, marker='o')
plt.xlabel('Test')
plt.ylabel('Runs')
plt.show()

# %%
xvals = np.random.randint(0, 100, 
            size=10, dtype=np.uint8)
yvals = np.random.randint(0, 100, 
               size=10, dtype=np.uint8)
plt.scatter(xvals,yvals, marker="o")
plt.show()

# %%
units = ['unit1', 'unit2', 'unit3', 'unit4', 'unit5' ]
earnings = [20,35,42,70,27]
plt.pie(earnings, labels=units)
plt.show()

# %%
import pandas as pd
gdp_data = [8.36, 3.40, 2.61, 5.96, 2.44, 15.68]
countries = ['China', 'Germany', 'France',
                           'Japan', 'UK', 'US'  ]
gdp_series = pd.Series(gdp_data)
plt.figure(figsize=(8, 5))
chart = gdp_series.plot(kind='bar')
chart.set_title('Country - GDP')
chart.set_xlabel('Country')
chart.set_ylabel('GDP (Trillion $)')
chart.set_xticklabels(countries)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
city=['Delhi','Beijing','Washington','Tokyo','Moscow']
pos = np.arange(len(city))
Happiness_Index=[60,40,70,65,85]
 
plt.bar(pos,Happiness_Index,color='blue',edgecolor='black')
#plt.barh(pos,Happiness_Index,color='blue',edgecolor='black')
plt.xticks(pos, city)
plt.xlabel('City', fontsize=16)
plt.ylabel('Happiness_Index', fontsize=16)
plt.title('Barchart - Happiness index across cities',fontsize=20)
plt.show()

# %%
city=['Delhi','Beijing','Washington','Tokyo','Moscow']
Gender=['Male','Female']
pos = np.arange(len(city))
Happiness_Index_Male=[60,40,70,65,85]
Happiness_Index_Female=[30,60,70,55,75]
plt.figure(figsize=(5, 4))
plt.bar(pos,Happiness_Index_Male,color='blue',edgecolor='black')
plt.bar(pos,Happiness_Index_Female,color='pink',edgecolor='black',bottom=Happiness_Index_Male)
plt.xticks(pos, city)
plt.xlabel('City', fontsize=16)
plt.ylabel('Happiness_Index', fontsize=16)
plt.title('Stacked Barchart - Happiness index across cities',fontsize=18)
plt.legend(Gender,loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt
sales1 = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5]
sales2 = [3, 7, 9, 6, 4, 5, 14, 7, 6, 16, 12]
line_chart1 = plt.plot(range(1,12), sales1)
line_chart2 = plt.plot(range(1,12), sales2)
plt.title('Monthly sales of 2016 and 2017')
plt.xlabel('Sales')
plt.ylabel('Month')
plt.legend(['year 2016', 'year 2017'], loc=4)
plt.show()

# %%
import matplotlib.pyplot as plt
sales1 = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5]
sales2 = [3, 7, 9, 6, 4, 5, 14, 7, 6, 16, 12]
line_chart1 = plt.plot(range(1,12), sales1,'--')
line_chart2 = plt.plot(range(1,12), sales2,':')
plt.title('Monthly sales of 2016 and 2017')
plt.xlabel('Sales')
plt.ylabel('Month')
plt.legend(['year 2016', 'year 2017'], loc=4)
plt.show()

# %%
sales1 = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5]
sales2 = [3, 7, 9, 6, 4, 5, 14, 7, 6, 16, 12]
line_chart1 = plt.plot(range(1,12), sales1,'g')
line_chart2 = plt.plot(range(1,12), sales2,'m')
plt.title('Monthly sales of 2016 and 2017')
plt.xlabel('Sales')
plt.ylabel('Month')
plt.legend(['year 2016', 'year 2017'], loc=4)
plt.show()
