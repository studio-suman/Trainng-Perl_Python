# %%
import pandas as pd
import time
import math
import numpy as np
import string as str
import openpyxl
#import sqlite3
#from sqlalchemy import create_engine
#from importlib import reload
from datetime import datetime
import sys

infile =   r"C:\Users\HSASS\OneDrive - Wipro\Suman\ETR\Mapping\completeFile_part_1.csv"
infile2 =   r"C:\Users\HSASS\OneDrive - Wipro\Suman\ETR\Mapping\completeFile_part_1.csv"
outfile =  r"C:\Users\HSASS\OneDrive - Wipro\Suman\ETR\Mapping\completeFile_A2.csv"
map_file = r"C:\Users\HSASS\OneDrive - Wipro\Desktop\AIR\Ops_Template_v1.xlsx"
table = pd.read_csv(infile, engine='python',sep=',', quotechar='"', error_bad_lines=False)
table2 = pd.read_csv(infile2, engine='python',sep=',', quotechar='"', error_bad_lines=False)

# %%
vertical_stack = pd.concat([table, table2], axis=0)
# Out:
#                      INDT_ID  d_OPEN_POS d_ROLE_ID   d_ROLE_DESC  \
# 0  D180000000000086156652019           1  CDEVPRL3  DEVELOPER-L3
# 1  D180000000000086156652019           1  CDEVPRL3  DEVELOPER-L3
# 2  D180000000000086156652019           1  CDEVPRL3  DEVELOPER-L3
# 3  D180000000000086156652019           1  CDEVPRL3  DEVELOPER-L3
# 4  D180000000000086156652019           1  CDEVPRL3  DEVELOPER-L3
#
#   d_SUITE_EXP_RANGE             d_ESSENTIAL_SKILL d_ADDITIONAL_SKILLS  \
# 0           3-5YEAR  Enterprise RPA -BluePrism-L2
# 1           3-5YEAR  Enterprise RPA -BluePrism-L2
# 2           3-5YEAR  Enterprise RPA -BluePrism-L2
# 3           3-5YEAR  Enterprise RPA -BluePrism-L2
# 4           3-5YEAR  Enterprise RPA -BluePrism-L2
#
#   d_ALT_MAND_SKILL d_INDENT_BAND d_COST_CENT  ...    PROPOSABLE_F  \
# 0                       GROUP B2      WD8201  ...      PROPOSABLE
# 1                       GROUP B2      WD8201  ...      PROPOSABLE
# 2                       GROUP B2      WD8201  ...  NOT PROPOSABLE
# 3                       GROUP B2      WD8201  ...      PROPOSABLE
# 4                       GROUP B2      WD8201  ...  NOT PROPOSABLE
#
#        DRIVE_LOCK BU_MATCH DU_MATCH VERTICAL_MATCH ACCOUNT_MATCH SL_MATCH  \
# 0  Not Applicable        0        0              0             0        1
# 1  Not Applicable        1        1              0             0        0
# 2      Drive Lock        1        1              0             0        0
# 3  Not Applicable        0        0              0             0        0
# 4      Drive Lock        1        1              0             0        0
#
#   LOCATION_MATCH      status  \
# 0              0  Proposable
# 1              0  Proposable
# 2              1  DRIVe Lock
# 3              0  Proposable
# 4              0  DRIVe Lock
#
#                                    Matching_Criteria
# 0  Allocatable Supply from Bench from different l...
# 1  Allocatable Supply from Bench from different l...
# 2  Matching Supply within DU but locked in Accoun...
# 3  Allocatable Supply from Bench from different l...
# 4           Matching Supply with location constraint
#
# [5 rows x 93 columns]

# %%
#mdata = pd.read_excel(map_file, sheet_name='Sheet1')
#final = table.merge(mdata, on = "CUSTOMER_NO", how='left') # adding data to same dataframe after merge
#odata = final.query('Sector != [""]')
#odata = final[final['Sector'].notnull()]
#final['INDENT_CREATED_ON'] = pd.to_datetime(final['INDENT_CREATED_ON'])
#mask = final['INDENT_CREATED_ON'].dt.month >= 10 # Month Filter Flag
vertical_stack.to_csv(outfile,index=False)
