# %% [markdown]
# ## Math Calculus

# %%
#import functions
import numpy as np
import scipy as sp
import sympy as symp
import matplotlib.pyplot as plt
from rdkit import Chem
import warnings
warnings.filterwarnings('ignore')

# %%
x = symp.symbols('x', real=True)
f = symp.sin(x)**2 * symp.exp(x)  # type: ignore
f
# Out:
# exp(x)*sin(x)**2

# %%
g = symp.integrate(f,x).simplify()
g
# Out:
# (-sin(2*x) - cos(2*x)/2 + 5/2)*exp(x)/5

# %%
# Create numpy arrays for plotting

x_vals = np.linspace(-2, 2, 1000)
y_vals = np.array([complex(f.subs(x, val)) for val in x_vals], dtype=complex)
z_vals = np.array([complex(g.subs(x, val)) for val in x_vals], dtype=complex)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, z_vals)
plt.title('f(x) = sin³(x)·e^(5x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()
